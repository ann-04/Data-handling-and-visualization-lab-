# %%
import requests

# %%
# !pip install --upgrade 'library'

# %%
r= requests.get('https://www.romexchange.com/')
r
# Out:
# <Response [406]>

# %%
r.status_code
# Out:
# 406

# %%
url = 'https://groww.in/stocks?utm_source=Paid_Search&utm_medium=CPC&utm_campaign=Generic_Stocks&gad_source=1&gclid=CjwKCAjw17qvBhBrEiwA1rU9w1nDaCpCcuGzZ1zgR5mHFDdnqLK3VOHZkt_BNKmlCmQWtVYBSQsKHBoCiYUQAvD_BwE'

headers = {'Content-type': 'application/json'}

# %%
url
# Out:
# 'https://groww.in/stocks?utm_source=Paid_Search&utm_medium=CPC&utm_campaign=Generic_Stocks&gad_source=1&gclid=CjwKCAjw17qvBhBrEiwA1rU9w1nDaCpCcuGzZ1zgR5mHFDdnqLK3VOHZkt_BNKmlCmQWtVYBSQsKHBoCiYUQAvD_BwE'

# %%
headers
# Out:
# {'Content-type': 'application/json'}

# %%
url = 'https://groww.in/stocks?utm_source=Paid_Search&utm_medium=CPC&utm_campaign=Generic_Stocks&gad_source=1&gclid=CjwKCAjw17qvBhBrEiwA1rU9w1nDaCpCcuGzZ1zgR5mHFDdnqLK3VOHZkt_BNKmlCmQWtVYBSQsKHBoCiYUQAvD_BwE'
headers = {'User-Agent': 'XY','Content-type': 'application/json'}
r = requests.get(url, headers=headers)

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en" data-theme="light" style="color-scheme:light"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1" /><link rel="icon" href="/favicon32x32-groww.ico" /><link rel="preload" as="image" imagesrcset="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/stocksHeader.96834ea8.webp 1x, //assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/stocksHeader.96834ea8.webp 2x" /><link rel="preload" as="image" imagesrcset="//assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/qrCode.09fc6a50.svg 1x, //assets-netstorage.groww.in/web-assets/billion_groww_desktop/prod/_next/static/media/qrCode.09fc6a50.svg 2x" /><title>Stock Market LIVE - BSE, NSE &amp; Nifty | Sensex Share Price, Indian Stock/Share Market &amp; Stock Exchange | Groww</title><meta name="description" content="Share/Stock Market - LIVE BSE/NSE, Nifty 
# ...
